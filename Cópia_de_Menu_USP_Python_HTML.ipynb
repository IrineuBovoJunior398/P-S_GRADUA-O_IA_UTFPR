# %% [markdown]
# <a href="https://colab.research.google.com/github/IrineuBovoJunior398/P-S_GRADUA-O_IA_UTFPR/blob/main/C%C3%B3pia_de_Menu_USP_Python_HTML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML, display

html_content = """
<!DOCTYPE html>
<html>
<head>
    <style>
        body { font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); margin: 0; padding: 20px; min-height: 100vh; }
        .container { max-width: 800px; margin: 0 auto; background: white; border-radius: 20px; box-shadow: 0 20px 40px rgba(0,0,0,0.1); padding: 30px; }
        h1 { text-align: center; color: #333; margin-bottom: 30px; }
        select { width: 100%; padding: 15px; font-size: 16px; border: 2px solid #ddd; border-radius: 10px; background: white; margin-bottom: 20px; }
        optgroup { font-weight: bold; color: #555; }
        #courseCard { display: none; background: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%); border-radius: 20px; padding: 30px; box-shadow: 0 15px 35px rgba(0,0,0,0.1); animation: fadeIn 0.5s ease-in; }
        @keyframes fadeIn { from { opacity: 0; transform: translateY(20px); } to { opacity: 1; transform: translateY(0); } }
        .course-info { display: grid; grid-template-columns: repeat(auto-fit, minmax(250px, 1fr)); gap: 20px; }
        .info-item { background: white; padding: 20px; border-radius: 15px; box-shadow: 0 5px 15px rgba(0,0,0,0.08); }
        .info-label { font-weight: bold; color: #667eea; margin-bottom: 5px; }
        .info-value { color: #333; font-size: 16px; }
        .description { grid-column: 1 / -1; }
        .link { text-decoration: none; color: #667eea; font-weight: bold; }
        .link:hover { text-decoration: underline; }
    </style>
</head>
<body>
    <div class="container">
        <h1>Dashboard Acadêmico USP</h1>
        <select id="courseSelect">
            <optgroup label="Graduação">
                <option value="medicina">Medicina (FMUSP)</option>
                <option value="direito">Direito (FDUSP)</option>
                <option value="engenharia_civil">Engenharia Civil (Poli-USP)</option>
                <option value="administracao">Administração (FEA-USP)</option>
            </optgroup>
            <optgroup label="Pós">
                <option value="pos_gestao_empresarial">Especialização em Gestão Empresarial (FEA)</option>
                <option value="pos_direito_empresarial">Pós em Direito Empresarial (FD)</option>
                <option value="pos_ti">Especialização em TI (IME)</option>
                <option value="pos_saude_publica">Pós em Saúde Pública (FSP)</option>
            </optgroup>
            <optgroup label="MBA">
                <option value="mba_financas">MBA Executivo em Finanças (FEA-USP)</option>
                <option value="mba_marketing">MBA em Marketing (FEA-USP)</option>
                <option value="mba_gestao_projetos">MBA em Gestão de Projetos (Poli-USP)</option>
                <option value="mba_negocios_internacionais">MBA em Negócios Internacionais (FEA-USP)</option>
            </optgroup>
            <optgroup label="Mestrado/Doutorado">
                <option value="mestrado_economia">Mestrado em Economia (FEA-USP)</option>
                <option value="doutorado_engenharia">Doutorado em Engenharia (Poli-USP)</option>
                <option value="mestrado_medicina">Mestrado em Medicina (FMUSP)</option>
                <option value="doutorado_direito">Doutorado em Direito (FDUSP)</option>
            </optgroup>
        </select>
        <div id="courseCard">
            <div class="course-info">
                <div class="info-item">
                    <div class="info-label">Nome</div>
                    <div id="courseName" class="info-value"></div>
                </div>
                <div class="info-item">
                    <div class="info-label">Duração</div>
                    <div id="courseDuration" class="info-value"></div>
                </div>
                <div class="info-item">
                    <div class="info-label">Carga Horária</div>
                    <div id="courseWorkload" class="info-value"></div>
                </div>
                <div class="info-item">
                    <div class="info-label">Investimento</div>
                    <div id="courseInvestment" class="info-value"></div>
                </div>
                <div class="info-item">
                    <div class="info-label">Foco</div>
                    <div id="courseFocus" class="info-value"></div>
                </div>
                <div class="info-item description">
                    <div class="info-label">Descrição</div>
                    <div id="courseDescription" class="info-value"></div>
                </div>
                <div class="info-item">
                    <div class="info-label">Matriz Curricular</div>
                    <div id="courseLink" class="info-value"><a id="courseLinkHref" href="#" class="link" target="_blank">Acessar Matriz</a></div>
                </div>
            </div>
        </div>
    </div>
    <script>
        const courses = {
            medicina: {
                name: 'Medicina (FMUSP)',
                duration: '6 anos',
                workload: '6.000 horas',
                investment: 'Gratuito (Universidade Pública)',
                focus: 'Mercado / Acadêmico',
                description: 'Formação completa em Medicina com ênfase em prática clínica e pesquisa.',
                link: 'https://www.fm.usp.br/graduacao/medicina/'
            },
            direito: {
                name: 'Direito (FDUSP)',
                duration: '5 anos',
                workload: '5.000 horas',
                investment: 'Gratuito',
                focus: 'Mercado / Acadêmico',
                description: 'Programa renomado em Direito com foco em teoria e prática jurídica.',
                link: 'https://www.direito.usp.br/'
            },
            engenharia_civil: {
                name: 'Engenharia Civil (Poli-USP)',
                duration: '5 anos',
                workload: '5.000 horas',
                investment: 'Gratuito',
                focus: 'Mercado',
                description: 'Engenharia com ênfase em projetos de infraestrutura e sustentabilidade.',
                link: 'https://www.poli.usp.br/graduacao/engenharia-civil/'
            },
            administracao: {
                name: 'Administração (FEA-USP)',
                duration: '4 anos',
                workload: '4.400 horas',
                investment: 'Gratuito',
                focus: 'Mercado',
                description: 'Formação em gestão empresarial e finanças.',
                link: 'https://www.fea.usp.br/graduacao/administracao'
            },
            pos_gestao_empresarial: {
                name: 'Especialização em Gestão Empresarial (FEA)',
                duration: '18 meses',
                workload: '360 horas',
                investment: 'R$ 25.000',
                focus: 'Mercado',
                description: 'Programa lato sensu para profissionais de gestão.',
                link: 'https://www.fea.usp.br/pos-graduacao-lato'
            },
            pos_direito_empresarial: {
                name: 'Pós em Direito Empresarial (FD)',
                duration: '12 meses',
                workload: '360 horas',
                investment: 'R$ 20.000',
                focus: 'Mercado',
                description: 'Especialização em direito societário e contratos.',
                link: 'https://www.direito.usp.br/pos-graduacao'
            },
            pos_ti: {
                name: 'Especialização em TI (IME)',
                duration: '18 meses',
                workload: '400 horas',
                investment: 'R$ 22.000',
                focus: 'Mercado',
                description: 'Foco em desenvolvimento e cibersegurança.',
                link: 'https://www.ime.usp.br/pos-graduacao'
            },
            pos_saude_publica: {
                name: 'Pós em Saúde Pública (FSP)',
                duration: '12 meses',
                workload: '360 horas',
                investment: 'R$ 18.000',
                focus: 'Mercado / Acadêmico',
                description: 'Epidemiologia e políticas de saúde.',
                link: 'https://www.fsp.usp.br/pos-graduacao'
            },
            mba_financas: {
                name: 'MBA Executivo em Finanças (FEA-USP)',
                duration: '18 meses',
                workload: '420 horas',
                investment: 'R$ 60.000',
                focus: 'Mercado',
                description: 'Programa executivo para finanças corporativas.',
                link: 'https://www.fea.usp.br/mba-financas'
            },
            mba_marketing: {
                name: 'MBA em Marketing (FEA-USP)',
                duration: '18 meses',
                workload: '400 horas',
                investment: 'R$ 55.000',
                focus: 'Mercado',
                description: 'Estratégias de marketing digital e tradicional.',
                link: 'https://www.fea.usp.br/mba-marketing'
            },
            mba_gestao_projetos: {
                name: 'MBA em Gestão de Projetos (Poli-USP)',
                duration: '18 meses',
                workload: '420 horas',
                investment: 'R$ 50.000',
                focus: 'Mercado',
                description: 'Certificação PMP integrada.',
                link: 'https://www.poli.usp.br/mba-gestao-projetos'
            },
            mba_negocios_internacionais: {
                name: 'MBA em Negócios Internacionais (FEA-USP)',
                duration: '18 meses',
                workload: '400 horas',
                investment: 'R$ 58.000',
                focus: 'Mercado',
                description: 'Comércio exterior e globalização.',
                link: 'https://www.fea.usp.br/mba-negocios-internacionais'
            },
            mestrado_economia: {
                name: 'Mestrado em Economia (FEA-USP)',
                duration: '24 meses',
                workload: 'Não fixa (créditos)',
                investment: 'Bolsas disponíveis / Gratuito',
                focus: 'Acadêmico',
                description: 'Pesquisa avançada em economia teórica e aplicada.',
                link: 'https://www.fea.usp.br/pos-graduacao-stricto/economia'
            },
            doutorado_engenharia: {
                name: 'Doutorado em Engenharia (Poli-USP)',
                duration: '48 meses',
                workload: 'Não fixa',
                investment: 'Bolsas / Gratuito',
                focus: 'Acadêmico',
                description: 'Pesquisa em engenharia avançada.',
                link: 'https://www.poli.usp.br/pos-graduacao'
            },
            mestrado_medicina: {
                name: 'Mestrado em Medicina (FMUSP)',
                duration: '24 meses',
                workload: 'Não fixa',
                investment: 'Bolsas / Gratuito',
                focus: 'Acadêmico',
                description: 'Pesquisa clínica e básica.',
                link: 'https://www.fm.usp.br/pos-graduacao'
            },
            doutorado_direito: {
                name: 'Doutorado em Direito (FDUSP)',
                duration: '48 meses',
                workload: 'Não fixa',
                investment: 'Bolsas / Gratuito',
                focus: 'Acadêmico',
                description: 'Teoria e história do direito.',
                link: 'https://www.direito.usp.br/pos-graduacao-stricto'
            }
        };

        document.getElementById('courseSelect').addEventListener('change', function() {
            const selectedValue = this.value;
            const card = document.getElementById('courseCard');
            if (selectedValue && courses[selectedValue]) {
                const course = courses[selectedValue];
                document.getElementById('courseName').textContent = course.name;
                document.getElementById('courseDuration').textContent = course.duration;
                document.getElementById('courseWorkload').textContent = course.workload;
                document.getElementById('courseInvestment').textContent = course.investment;
                document.getElementById('courseFocus').textContent = course.focus;
                document.getElementById('courseDescription').textContent = course.description;
                const linkEl = document.getElementById('courseLinkHref');
                linkEl.href = course.link;
                linkEl.textContent = 'Acessar Matriz';
                card.style.display = 'block';
            } else {
                card.style.display = 'none';
            }
        });
    </script>
</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#         body { font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); margin: 0; padding: 20px; min-height: 100vh; }
#         .container { max-width: 800px; margin: 0 auto; background: white; border-radius: 20px; box-shadow: 0 20px 40px rgba(0,0,0,0.1); padding: 30px; }
#         h1 { text-align: center; color: #333; margin-bottom: 30px; }
#         select { width: 100%; padding: 15px; font-size: 16px; border: 2px solid #ddd; border-radius: 10px; background: white; margin-bottom: 20px; }
#         optgroup { font-weight: bold; color: #555; }
#         #courseCard { display: none; background: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%); border-radius: 20px; padding: 30px; box-shadow: 0 15px 35px rgba(0,0,0,0.1); animation: fadeIn 0.5s ease-in; }
# ...
