# %% [markdown]
# <a href="https://colab.research.google.com/github/IrineuBovoJunior398/P-S_GRADUA-O_IA_UTFPR/blob/main/EXEMPLO_PRATICO_FRONT_END.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

html_code = """
<!DOCTYPE html>
<html lang="pt-BR">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Exemplo Front-end no Colab</title>
    <style>
        body { font-family: Arial, sans-serif; text-align: center; padding: 50px; transition: background-color 0.5s ease; }
        button { padding: 15px 30px; font-size: 18px; cursor: pointer; border: none; background-color: #007bff; color: white; border-radius: 8px; }
        button:hover { background-color: #0056b3; }
        #mensagem { margin-top: 20px; font-size: 24px; color: #333; }
    </style>
</head>
<body>
    <h1>Olá, Front-end no Colab!</h1>
    <button id="meuBotao">Clique aqui!</button>
    <p id="mensagem"></p>

    <script>
        const botao = document.getElementById('meuBotao');
        const mensagem = document.getElementById('mensagem');
        botao.addEventListener('click', function() {
            document.body.style.backgroundColor = '#ffeb3b';
            mensagem.textContent = 'Botão clicado! Funciona no Colab.';
        });
    </script>
</body>
</html>
"""

HTML(html_code)
# Out:
# <!DOCTYPE html>
# <html lang="pt-BR">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Exemplo Front-end no Colab</title>
#     <style>
#         body { font-family: Arial, sans-serif; text-align: center; padding: 50px; transition: background-color 0.5s ease; }
#         button { padding: 15px 30px; font-size: 18px; cursor: pointer; border: none; background-color: #007bff; color: white; border-radius: 8px; }
#         button:hover { background-color: #0056b3; }
#         #mensagem { margin-top: 20px; font-size: 24px; color: #333; }
#     </style>
# </head>
# <body>
#     <h1>Olá, Front-end no Colab!</h1>
#     <button id="meuBotao">Clique aqui!</button>
#     <p id="mensagem"></p>
#
#     <script>
#         const botao = document.getElementById('meuBotao');
#         const mensagem = document.getElementById('mensagem');
#         botao.addEventListener('click', function() {
# ...
