# %% [markdown]
# <a href="https://colab.research.google.com/github/IrineuBovoJunior398/P-S_GRADUA-O_IA_UTFPR/blob/main/DIAGRAMA_VENN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
from matplotlib_venn import venn3, venn3_circles

# Contagens das regiões
v = venn3(subsets=(3, 2, 1, 1, 1, 2, 3),  # (sóA, A∩B, sóB, A∩C, B∩C, sóC, ABC)
          set_labels=('Inglês (A)', 'Espanhol (B)', 'Francês (C)'))

plt.title('Diagrama de Venn: Idiomas Falados (U=20)')
plt.show()
